# %% [markdown]
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:center; border-radius:10px 10px; margin-bottom: 10px; padding: 10px;"><strong>ANÁLISE EXPLORATÓRIA DE CHURN DO BLUE BANK</strong></p>

# %% [markdown]
# <div style="text-align: center; margin-bottom: 20px;">
#   <img src="../03-Recursos/churn.jpg" alt="Churn Analysis" style="width: 600px; display: block; margin-left: auto; margin-right: auto;"/>
# </div>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:150%; text-align:center; border-radius:10px 10px; margin-bottom: -15px;"><strong>SUMÁRIO</strong></p>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">1. INTRODUÇÃO 🚀</span></strong></p>](#1) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">2. OBJETIVO 🎯</span></strong></p>](#2) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">3. IMPORTAÇÃO DE BIBLIOTECAS 📚</span></strong></p>](#3) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">4. CARREGAMENTO DOS DADOS 🔄</span></strong></p>](#4) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">5. LIMPEZA E PRÉ-PROCESSAMENTO DOS DADOS 🔍</span></strong></p>](#5) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">6. ANÁLISE EXPLORATÓRIA DE DADOS (AED/EDA) 💡</span></strong></p>](#6) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">7. INSIGHTS E CONCLUSÕES 📊</span></strong></p>](#7) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">8. RECOMENDAÇÕES 📝</span></strong></p>](#8) <br>
#
# [<p style="background-color:#14274C; font-family:Montserrat; font-size:120%; text-align:left; border-radius:10px 10px; padding-left: 50px; margin-bottom: -20px;"><strong><span style="color:#8BD5EA">9. CONCLUSÃO 🏁</span></strong></p>](#9) <br>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="1"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>1. INTRODUÇÃO 🚀</strong></p>
#
# - **Este projeto de Análise de Churn do Blue Bank tem como objetivo explorar e analisar o comportamento dos clientes do banco para identificar os principais fatores que influenciam suas decisões de permanecer ou deixar o banco. O conjunto de dados utilizado contém informações diversas sobre os clientes, como idade, saldo bancário, status de membro ativo, número de produtos, e possibilidade de churn, entre outros. A descrição detalhada de cada uma das colunas será abordada na seção de Limpeza e Pré-processamento dos Dados.**

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="2"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>2. OBJETIVO 🎯</strong></p>
#
# - **O objetivo principal deste projeto é conduzir uma Análise Exploratória de Dados (EDA) sobre o conjunto de dados de churn dos clientes do Blue Bank. A análise busca identificar padrões e fatores que influenciam os clientes a deixarem o banco, utilizando visualizações e estatísticas descritivas para responder a perguntas de negócio. Vamos investigar a influência de variáveis como idade, saldo bancário, número de produtos, geografia e atividade no banco para compreender melhor o comportamento de churn.**
#
#     - **Analisar o impacto de características como idade, saldo bancário, número de produtos e atividade no banco sobre a probabilidade de churn.**
#     - **Verificar se há uma correlação entre a localização geográfica dos clientes e suas taxas de churn.**
#     - **Avaliar se a posse de cartão de crédito está relacionada com a retenção de clientes.**
#     - **Explorar o efeito de variáveis como salário estimado, tempo de relacionamento e pontuação de crédito na decisão de churn.**
#     - **Identificar padrões de churn entre grupos específicos, como idade, país, gênero, e traçar o perfil geral dos clientes.**
#
# - **Essas perguntas têm como objetivo fornecer insights que possam guiar o Blue Bank na melhoria de suas estratégias de retenção de clientes, ajudando a reduzir as taxas de churn e aumentar a satisfação dos clientes.**
#
# </div>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="3"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>3. IMPORTAÇÃO DE BIBLIOTECAS E CONFIGURAÇÃO DE ESTILO 📚</strong></p>
#
# - **Nesta seção, importamos todas as bibliotecas essenciais para a execução da análise de dados, como Pandas, Matplotlib, Seaborn e NumPy, que são fundamentais para a manipulação de dados, visualização e análise estatística. Adicionalmente, configuramos estilos visuais para assegurar que todas as visualizações sejam consistentes e reflitam a identidade visual do Blue Bank, utilizando uma paleta de cores em tons de azul. Além disso, exibimos as versões de cada biblioteca utilizada para garantir a reprodutibilidade e documentação do ambiente de desenvolvimento.**
#
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib
import seaborn as sns
import numpy as np
from platform import python_version

# Configuração de estilos visuais para os gráficos
sns.set(style="whitegrid")  # Define o estilo do Seaborn para melhor visualização
blue_palette = sns.color_palette("Blues")  # Cria uma paleta de cores em tons de azul
sns.set_palette(blue_palette)  # Aplica a paleta de cores aos gráficos

# Tabela de versões das bibliotecas e do Python
library_versions = {
    "Pandas": pd.__version__,
    "Matplotlib": matplotlib.__version__,
    "Seaborn": sns.__version__,
    "NumPy": np.__version__
}

# Exibindo as versões das bibliotecas
print("Versões das Bibliotecas:\n")
print(f"{'Biblioteca':<20} | {'Versão':>10}")
for nome, versao in library_versions.items():
    print(f"{nome:<20} | {versao:>10}")

# Versão do Python
print("\nVersão do Python:")
print(python_version())
# Out:
# Versões das Bibliotecas:
#
# Biblioteca           |     Versão
# Pandas               |      1.5.3
# Matplotlib           |      3.7.1
# Seaborn              |     0.12.2
# NumPy                |     1.24.3
#
# Versão do Python:
# 3.11.4

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="4"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>4. CARREGAMENTO DOS DADOS 🔄</strong></p>
#
# - **Nesta seção, carregamos o conjunto de dados do Blue Bank, que contém informações detalhadas sobre os clientes e seus status de churn. Este passo é crucial para começar a nossa análise exploratória.**
#
# </div>

# %%
# Carregando os dados do arquivo CSV
data_path = "../01-Base-de-Dados/blue-bank-churn.csv"  # Caminho da pasta com arquivo de análise
df = pd.read_csv(data_path)

# Exibindo as primeiras linhas do DataFrame para verificar a importação
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# Exibindo informações básicas sobre o DataFrame para entender a estrutura dos dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="5"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>5. LIMPEZA E PRÉ-PROCESSAMENTO DOS DADOS 🔍</strong></p>
#
# - **Antes de iniciar a análise exploratória, é essencial garantir que os dados estejam limpos e bem formatados. Esta seção aborda a limpeza de dados, tratamento de valores nulos, correção de tipos de dados e qualquer outra transformação necessária para preparar o dataset. Estas etapas são cruciais para garantir a qualidade e precisão das análises subsequentes.**
#
# </div>

# %%
#Exibição do Dataframe atual para avaliarmos possíveis mudanças:
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# Dicionário com as descrições detalhadas das colunas do DataFrame. Esta informação é crucial para entender o significado de cada campo e sua importância para a análise de churn.
descricao_colunas = {
    "RowNumber": "Número do registro (linha) no dataset, usado apenas como índice.",
    "CustomerId": "Identificador único do cliente no banco, crucial para identificação individual.",
    "Surname": "Sobrenome do cliente, não tem impacto direto na análise.",
    "CreditScore": "Pontuação de crédito do cliente, indicando sua solvência e potencial risco financeiro.",
    "Geography": "País de residência do cliente, importante para análise regional de churn.",
    "Gender": "Gênero do cliente, útil para análise demográfica.",
    "Age": "Idade do cliente, um fator significativo na decisão de produtos bancários.",
    "Tenure": "Número de anos que o cliente está com o banco, indicativo de lealdade e satisfação.",
    "Balance": "Saldo atual na conta bancária do cliente, pode indicar satisfação com o banco.",
    "NumOfProducts": "Número de produtos bancários que o cliente utiliza, reflete a profundidade do relacionamento.",
    "HasCrCard": "Indica se o cliente possui um cartão de crédito (1 = Sim, 0 = Não), relevante para serviços cruzados.",
    "IsActiveMember": "Indica se o cliente é um membro ativo (1 = Sim, 0 = Não), importante para engajamento.",
    "EstimatedSalary": "Salário estimado anual do cliente, correlaciona com potencial de investimento.",
    "Exited": "Indica se o cliente deixou o banco (1 = Sim, 0 = Não), variável-alvo para análise de churn."
}

# Convertendo o dicionário em um DataFrame para facilitar a visualização e entendimento das colunas
df_descricao_colunas = pd.DataFrame(list(descricao_colunas.items()), columns=['Coluna', 'Descrição'])

# Exibindo o DataFrame para visualização das descrições das colunas
df_descricao_colunas
# Out:
#              Coluna                                          Descrição
# 0         RowNumber  Número do registro (linha) no dataset, usado a...
# 1        CustomerId  Identificador único do cliente no banco, cruci...
# 2           Surname  Sobrenome do cliente, não tem impacto direto n...
# 3       CreditScore  Pontuação de crédito do cliente, indicando sua...
# 4         Geography  País de residência do cliente, importante para...
# 5            Gender  Gênero do cliente, útil para análise demográfica.
# 6               Age  Idade do cliente, um fator significativo na de...
# 7            Tenure  Número de anos que o cliente está com o banco,...
# 8           Balance  Saldo atual na conta bancária do cliente, pode...
# 9     NumOfProducts  Número de produtos bancários que o cliente uti...
# 10        HasCrCard  Indica se o cliente possui um cartão de crédit...
# 11   IsActiveMember  Indica se o cliente é um membro ativo (1 = Sim...
# ...

# %%
# Exibindo a soma de valores nulos para cada coluna no DataFrame
null_values = df.isnull().sum()

# Verificando se há valores nulos e exibindo os resultados
print("Quantidade de valores nulos por coluna no dataset:")
print(null_values)
# Out:
# Quantidade de valores nulos por coluna no dataset:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Contando o número de linhas duplicadas no DataFrame
num_duplicatas = df.duplicated().sum()

# Exibindo o número de linhas duplicadas
print(f"Total de linhas duplicadas: {num_duplicatas}")
# Out:
# Total de linhas duplicadas: 0

# %%
# Renomeando as colunas do DataFrame para nomes em português com estilo snake_case
colunas_traduzidas = {
    'RowNumber': 'numero_linha',
    'CustomerId': 'id_cliente',
    'Surname': 'sobrenome',
    'CreditScore': 'pontuacao_credito',
    'Geography': 'pais',
    'Gender': 'genero',
    'Age': 'idade',
    'Tenure': 'tempo_relacionamento',
    'Balance': 'saldo',
    'NumOfProducts': 'numero_produtos',
    'HasCrCard': 'possui_cartao_credito',
    'IsActiveMember': 'membro_ativo',
    'EstimatedSalary': 'salario_estimado',
    'Exited': 'saiu_banco'
}

# Aplicando as novas nomenclaturas das colunas ao DataFrame
df.rename(columns=colunas_traduzidas, inplace=True)

# Exibindo as primeiras linhas do DataFrame para verificar as novas nomenclaturas de colunas
df.head()
# Out:
#    numero_linha  id_cliente sobrenome  pontuacao_credito    pais  genero  \
# 0             1    15634602  Hargrave                619  France  Female
# 1             2    15647311      Hill                608   Spain  Female
# 2             3    15619304      Onio                502  France  Female
# 3             4    15701354      Boni                699  France  Female
# 4             5    15737888  Mitchell                850   Spain  Female
#
#    idade  tempo_relacionamento      saldo  numero_produtos  \
# 0     42                     2       0.00                1
# 1     41                     1   83807.86                1
# 2     42                     8  159660.80                3
# 3     39                     1       0.00                2
# 4     43                     2  125510.82                1
#
#    possui_cartao_credito  membro_ativo  salario_estimado  saiu_banco
# 0                      1             1         101348.88           1
# ...

# %%
# Mostrando os valores únicos presentes nas colunas 'pais' e 'genero'
print("Valores únicos na coluna 'pais':", df['pais'].unique())
print("Valores únicos na coluna 'genero':", df['genero'].unique())

# Dicionários de tradução para as colunas 'pais' e 'genero'
traducao_paises = {
    'France': 'França',
    'Spain': 'Espanha',
    'Germany': 'Alemanha'
}

traducao_genero = {
    'Female': 'Feminino',
    'Male': 'Masculino'
}

# Aplicando as traduções
df['pais'] = df['pais'].map(traducao_paises)
df['genero'] = df['genero'].map(traducao_genero)

# Exibindo as primeiras linhas do DataFrame para verificar as traduções
print("\nApós a tradução:")
df[['pais', 'genero']].head()
# Out:
# Valores únicos na coluna 'pais': ['France' 'Spain' 'Germany']
# Valores únicos na coluna 'genero': ['Female' 'Male']
#
# Após a tradução:
#       pais    genero
# 0   França  Feminino
# 1  Espanha  Feminino
# 2   França  Feminino
# 3   França  Feminino
# 4  Espanha  Feminino

# %%
# Removendo colunas desnecessárias para a análise de churn
# As colunas 'numero_linha', id_cliente e 'sobrenome' são removidas porque não contribuem para a análise ou insights sobre o churn dos clientes.

# Removendo as colunas do DataFrame
df.drop(['numero_linha','id_cliente', 'sobrenome'], axis=1, inplace=True)

# Exibindo as primeiras linhas do DataFrame após a remoção das colunas para confirmar a alteração
print("DataFrame após a remoção das colunas 'numero_linha', 'id_cliente' e 'sobrenome':")
df.head()
# Out:
# DataFrame após a remoção das colunas 'numero_linha', 'id_cliente' e 'sobrenome':
#    pontuacao_credito     pais    genero  idade  tempo_relacionamento  \
# 0                619   França  Feminino     42                     2
# 1                608  Espanha  Feminino     41                     1
# 2                502   França  Feminino     42                     8
# 3                699   França  Feminino     39                     1
# 4                850  Espanha  Feminino     43                     2
#
#        saldo  numero_produtos  possui_cartao_credito  membro_ativo  \
# 0       0.00                1                      1             1
# 1   83807.86                1                      0             1
# 2  159660.80                3                      1             0
# 3       0.00                2                      0             0
# 4  125510.82                1                      1             1
#
#    salario_estimado  saiu_banco
# ...

# %%
# Atualização do dicionário com as descrições das colunas do DataFrame após as modificações
descricao_colunas_atualizada = {
    
    'pontuacao_credito': 'Pontuação de crédito do cliente, indicando sua solvência e potencial risco financeiro.',
    'pais': 'País de residência do cliente, importante para análise regional de churn.',
    'genero': 'Gênero do cliente, útil para análise demográfica.',
    'idade': 'Idade do cliente, um fator significativo na decisão de produtos bancários.',
    'tempo_relacionamento': 'Número de anos que o cliente está com o banco, indicativo de lealdade e satisfação.',
    'saldo': 'Saldo atual na conta bancária do cliente, pode indicar satisfação com o banco.',
    'numero_produtos': 'Número de produtos bancários que o cliente utiliza, reflete a profundidade do relacionamento.',
    'possui_cartao_credito': 'Indica se o cliente possui um cartão de crédito (1 = Sim, 0 = Não), relevante para serviços cruzados.',
    'membro_ativo': 'Indica se o cliente é um membro ativo (1 = Sim, 0 = Não), importante para engajamento.',
    'salario_estimado': 'Salário estimado anual do cliente, correlaciona com potencial de investimento.',
    'saiu_banco': 'Indica se o cliente deixou o banco (1 = Sim, 0 = Não), variável-alvo para análise de churn.'
}

# Convertendo o dicionário atualizado em um DataFrame para facilitar a visualização e entendimento das colunas
df_descricao_colunas_atualizada = pd.DataFrame(list(descricao_colunas_atualizada.items()), columns=['Coluna', 'Descrição'])

# Exibindo o DataFrame atualizado para visualização das descrições das colunas
print("Descrição atualizada das colunas do DataFrame:")
df_descricao_colunas_atualizada
# Out:
# Descrição atualizada das colunas do DataFrame:
#                    Coluna                                          Descrição
# 0       pontuacao_credito  Pontuação de crédito do cliente, indicando sua...
# 1                    pais  País de residência do cliente, importante para...
# 2                  genero  Gênero do cliente, útil para análise demográfica.
# 3                   idade  Idade do cliente, um fator significativo na de...
# 4    tempo_relacionamento  Número de anos que o cliente está com o banco,...
# 5                   saldo  Saldo atual na conta bancária do cliente, pode...
# 6         numero_produtos  Número de produtos bancários que o cliente uti...
# 7   possui_cartao_credito  Indica se o cliente possui um cartão de crédit...
# 8            membro_ativo  Indica se o cliente é um membro ativo (1 = Sim...
# 9        salario_estimado  Salário estimado anual do cliente, correlacion...
# 10             saiu_banco  Indica se o cliente deixou o banco (1 = Sim, 0...

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="6"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6. ANÁLISE EXPLORATÓRIA DE DADOS (AED/EDA) 💡</strong></p>
#
# - **Nesta seção, conduzimos uma análise exploratória detalhada dos dados do Blue Bank, utilizando visualizações gráficas e estatísticas descritivas para identificar padrões e correlações que podem influenciar a decisão de um cliente em permanecer ou deixar o banco. Analisamos variáveis como idade, saldo, número de produtos e atividade do membro para compreender melhor os fatores que contribuem para o churn dos clientes. Esta etapa foi crucial para gerar insights e orientar as estratégias de retenção de clientes.**
#
#     - **Durante a análise, buscamos responder algumas das perguntas de negócio mais relevantes para entender o churn dos clientes do Blue Bank:**
#         - **Idade foi identificada como um fator crítico, com clientes mais velhos apresentando uma maior probabilidade de churn.**
#         - **O saldo bancário também influenciou o churn, com uma maior propensão de saída entre clientes com saldos elevados.**
#         - **A análise de clientes ativos e inativos revelou que membros ativos têm uma probabilidade significativamente menor de sair do banco.**
#         - **A variável país destacou que clientes da Alemanha têm maior probabilidade de churn em comparação com outros países.**
#         - **Não foram observadas correlações significativas entre posse de cartão de crédito, número de produtos e churn.**
#         - **O impacto do salário estimado e a pontuação de crédito sobre o churn mostrou-se fraco, sem correlações significativas.**
#
# - **A análise permitiu responder a questões centrais sobre o perfil de clientes mais propensos a churn, destacando fatores como idade, atividade no banco e localização geográfica.**
# </div>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.0 Separação das Variáveis em Quantitativas e Qualitativas</strong></p>
#
# - **Antes de iniciar a análise exploratória dos dados, é importante separar as variáveis em dois grupos: quantitativas e qualitativas.**
# - **As variáveis quantitativas representam dados numéricos contínuos, como idade, saldo e pontuação de crédito, enquanto as variáveis qualitativas representam categorias ou grupos, como país e gênero.**
# </div>

# %%
# Separando as variáveis quantitativas e qualitativas
colunas_quantitativas = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
colunas_qualitativas = df.select_dtypes(include=['object', 'category']).columns.tolist()

# Caso especial para binárias que podem ser tratadas como qualitativas
colunas_binarias = ['possui_cartao_credito', 'membro_ativo', 'saiu_banco']  
colunas_qualitativas.extend(x for x in colunas_binarias if x in df.columns)

# Removendo colunas binárias das quantitativas se estiverem presentes
colunas_quantitativas = [x for x in colunas_quantitativas if x not in colunas_binarias]

print("Colunas Quantitativas:", colunas_quantitativas)
print("Colunas Qualitativas:", colunas_qualitativas)
# Out:
# Colunas Quantitativas: ['pontuacao_credito', 'idade', 'tempo_relacionamento', 'saldo', 'numero_produtos', 'salario_estimado']
# Colunas Qualitativas: ['pais', 'genero', 'possui_cartao_credito', 'membro_ativo', 'saiu_banco']

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.1. Análise Descritiva das Variáveis Quantitativas</strong></p>
#
# - **A análise descritiva das variáveis quantitativas permite obter um panorama inicial das distribuições, valores médios, mínimos, máximos e a dispersão dos dados (desvio padrão). Identificar essas características é essencial para guiar as próximas análises, detectar outliers e compreender a variação nas diferentes variáveis.**
#
# As métricas de resumo fornecidas para cada variável quantitativa incluem:
#
# - **count**: Total de observações válidas para cada variável.
# - **mean**: Média dos valores observados.
# - **std**: Desvio padrão, que representa a dispersão dos valores em relação à média.
# - **min** e **max**: Valores mínimos e máximos observados.
# - **25%, 50% (mediana), 75%**: Quartis, que dividem a distribuição dos dados em partes proporcionais, indicando a dispersão.
#
# </div>

# %%
# Resumo estatístico das variáveis quantitativas
descricao_quantitativas = df[colunas_quantitativas].describe()
descricao_quantitativas
# Out:
#        pontuacao_credito         idade  tempo_relacionamento          saldo  \
# count       10000.000000  10000.000000          10000.000000   10000.000000
# mean          650.528800     38.921800              5.012800   76485.889288
# std            96.653299     10.487806              2.892174   62397.405202
# min           350.000000     18.000000              0.000000       0.000000
# 25%           584.000000     32.000000              3.000000       0.000000
# 50%           652.000000     37.000000              5.000000   97198.540000
# 75%           718.000000     44.000000              7.000000  127644.240000
# max           850.000000     92.000000             10.000000  250898.090000
#
#        numero_produtos  salario_estimado
# count     10000.000000      10000.000000
# mean          1.530200     100090.239881
# std           0.581654      57510.492818
# min           1.000000         11.580000
# 25%           1.000000      51002.110000
# ...

# %% [markdown]
# ---
#
# ### Observações:
# - A **idade média** dos clientes é de aproximadamente **38 anos**, com o cliente mais jovem tendo **18 anos** e o mais velho **92 anos**. Isso sugere uma ampla diversidade etária entre os clientes.
# - A **pontuação de crédito** varia entre **350** e **850**, com uma média de **650**, o que indica que a maioria dos clientes possui uma pontuação de crédito razoável, mas há uma variação considerável.
# - O **saldo bancário** varia drasticamente, com muitos clientes tendo saldo próximo de **0**, mas o saldo máximo alcança até **250 mil**. Isso sugere que existe uma parcela significativa de clientes com alto poder aquisitivo, mas também muitos com baixo saldo.
# - A **quantidade média de produtos bancários** é **1.53**, com um máximo de **4 produtos** por cliente. A maioria dos clientes usa apenas um ou dois produtos bancários.
# - O **salário estimado** tem uma média de **100 mil**, com alguns clientes recebendo salários bem baixos (a partir de **11**), enquanto outros alcançam quase **200 mil** por ano.
#
# Esses resultados nos dão uma visão inicial da diversidade e das características financeiras dos clientes, o que nos ajudará a entender melhor os fatores que podem estar associados ao churn nas próximas etapas da análise.

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.2. Análise Descritiva das Variáveis Categóricas</strong></p>
#
# - **Nesta etapa, analisaremos a distribuição das variáveis categóricas, visualizando as frequências absolutas e relativas (em porcentagem). O objetivo é entender a composição dos clientes em termos de país, gênero, posse de cartão de crédito, atividade no banco, e se deixaram ou não o banco.**
#
# </div>

# %%
# Resumo de frequências e porcentagens para variáveis categóricas
for coluna in colunas_qualitativas:
    print(f"Distribuição de frequência e porcentagem para {coluna}:")
    frequencia = df[coluna].value_counts()
    percentual = df[coluna].value_counts(normalize=True) * 100  # Calcula a porcentagem
    distribuicao = pd.DataFrame({'Frequência': frequencia, 'Porcentagem (%)': percentual.round(2)})
    print(distribuicao)
    print("\n")
# Out:
# Distribuição de frequência e porcentagem para pais:
#           Frequência  Porcentagem (%)
# França          5014            50.14
# Alemanha        2509            25.09
# Espanha         2477            24.77
#
#
# Distribuição de frequência e porcentagem para genero:
#            Frequência  Porcentagem (%)
# Masculino        5457            54.57
# Feminino         4543            45.43
#
#
# Distribuição de frequência e porcentagem para possui_cartao_credito:
#    Frequência  Porcentagem (%)
# 1        7055            70.55
# 0        2945            29.45
#
#
# Distribuição de frequência e porcentagem para membro_ativo:
#    Frequência  Porcentagem (%)
# 1        5151            51.51
# 0        4849            48.49
#
#
# Distribuição de frequência e porcentagem para saiu_banco:
#    Frequência  Porcentagem (%)
# 0        7963            79.63
# 1        2037            20.37

# %% [markdown]
# ---
#
# ### Observações:
# - A maior parte dos clientes pertence à **França**, seguida de **Alemanha** e **Espanha**.
# - A distribuição de **gênero** mostra uma ligeira predominância de **masculinos**.
# - **70.55%** dos clientes possuem cartão de crédito, e **51.51%** são membros ativos do banco.
# - A taxa de **churn** (clientes que deixaram o banco) é de **20.37%**, o que será analisado em mais detalhes nas próximas etapas.

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.3 Análise Gráfica das Variáveis Quantitativas</strong></p>
#
# - **Nesta seção, faremos uma análise gráfica das variáveis quantitativas para entender melhor a distribuição dos dados e a presença de outliers. Utilizaremos boxplots e histogramas para visualizar essas informações.**
# - **Os boxplots ajudam a identificar a mediana, quartis e possíveis valores atípicos (outliers), enquanto os histogramas, acompanhados pela curva de densidade Kernel (KDE), mostram a distribuição dos valores das variáveis.**
#
# </div>

# %%
# Configurações visuais para todos os gráficos
sns.set(style="whitegrid")

# Definindo a paleta de cores em tons de azul
blue_palette_box = sns.color_palette("Blues_r")  # Invertendo a paleta para o boxplot ficar mais claro
blue_palette_hist = sns.color_palette("Blues", as_cmap=True)  # Paleta normal para histogramas

# Número de variáveis quantitativas
num_var = len(colunas_quantitativas)

# Determinando o número de linhas e colunas
num_cols = 3  # Três conjuntos por linha
num_rows = (num_var + num_cols - 1) // num_cols  # Calcula o número necessário de linhas, arredondado para cima

# Criando a figura e definindo o número de linhas e colunas para os subplots
fig, axes = plt.subplots(nrows=num_rows * 2, ncols=num_cols, figsize=(15, 5 * num_rows))  # Cada variável ocupa duas linhas

# Loop para plotar box plots e histogramas para cada variável quantitativa
for i, coluna in enumerate(colunas_quantitativas):
    row = (i // num_cols) * 2  # Encontra a linha base para o par de gráficos (boxplot e histograma)
    col = i % num_cols  # Encontra a coluna para o par de gráficos

    # Box plot na parte superior usando tons de azul
    sns.boxplot(data=df, x=coluna, ax=axes[row, col], orient='h', palette=blue_palette_box)
    axes[row, col].set_title(f'Box Plot de {coluna}')
    axes[row, col].set_xlabel('')  # Limpar label de x se não necessário

    # Histograma diretamente abaixo do box plot, também em azul
    sns.histplot(df[coluna], kde=True, ax=axes[row + 1, col], color=blue_palette_hist(200))
    axes[row + 1, col].set_title(f'Histograma de {coluna}')

# Ajustando o layout para evitar sobreposição e melhorar a apresentação
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Observações:
# - A **pontuação de crédito** dos clientes varia entre **350** e **850**, com uma média de aproximadamente **650**. Observa-se uma leve assimetria à direita, indicando que há mais clientes com pontuação de crédito acima da média, mas alguns com pontuações bastante baixas (outliers).
# - A **idade média** dos clientes é de **38 anos**, com o cliente mais jovem tendo **18 anos** e o mais velho **92 anos**. A maioria dos clientes tem entre **30 e 50 anos**, com maior concentração na faixa dos **40 anos**.
# - O **tempo de relacionamento com o banco** apresenta uma distribuição relativamente uniforme, com leve concentração de clientes com **5 anos de relacionamento**. A maioria dos clientes tem entre **3 e 7 anos** de vínculo com o banco, sem outliers significativos.
# - O **saldo bancário** apresenta uma distribuição assimétrica, com muitos clientes mantendo saldo próximo de **0**, enquanto outros têm saldos consideravelmente altos, chegando a **250 mil**. A maioria parece ter saldos menores ou utilizar a conta de forma limitada.
# - A **quantidade de produtos bancários** é predominantemente de **1 ou 2 produtos**. Poucos clientes utilizam **3 ou 4 produtos**, com alguns outliers para **4 produtos**.
# - O **salário estimado** dos clientes varia entre **11 mil** e **200 mil** anuais, com uma média próxima de **100 mil**. A distribuição salarial é bastante uniforme, sem outliers significativos.
#
# Essas observações fornecem uma visão geral das características financeiras e demográficas dos clientes, que serão essenciais para analisar os fatores associados ao churn nas próximas etapas.

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.4 Análise Gráfica de Frequências das Variáveis Categóricas</strong></p>
#
# - **Nesta etapa, vamos analisar as variáveis categóricas presentes no conjunto de dados para compreender como as diferentes categorias estão distribuídas entre os clientes.**
# - **Para cada variável, será exibido um gráfico de barras que mostrará as contagens de cada categoria, juntamente com as porcentagens diretamente nas barras. Isso nos permitirá ter uma visão clara das proporções entre diferentes categorias, como país, gênero, e atividade dos clientes.**
#
# </div>

# %%
# Configurações visuais para todos os gráficos
sns.set(style="whitegrid")

# Definindo a paleta de cores em tons de azul
blue_palette = sns.color_palette("Blues")

# Número de variáveis qualitativas
num_var = len(colunas_qualitativas)

# Determinando o número de linhas e colunas
num_cols = 2  # Dois gráficos por linha
num_rows = (num_var + num_cols - 1) // num_cols  # Calcula o número necessário de linhas, arredondado para cima

# Criando a figura e definindo o número de linhas e colunas para os subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 5 * num_rows))

# Loop para plotar gráficos de barras para cada variável categórica
for i, coluna in enumerate(colunas_qualitativas):
    ax = axes[i // num_cols, i % num_cols]  # Encontra o subplot correspondente
    countplot = sns.countplot(x=coluna, data=df, palette=blue_palette, ax=ax)
    ax.set_title(f'Distribuição de {coluna}')
    ax.set_xlabel(coluna)
    ax.set_ylabel('Contagem')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0)  # Rotação dos labels para melhor visualização

    # Calculando e anotando as porcentagens em cada barra
    total = float(len(df))  # Número total de dados para calcular as porcentagens
    for p in countplot.patches:
        height = p.get_height()  # Altura da barra (contagem de cada categoria)
        percentage = f'{(height/total)*100:.1f}%'
        text_label = f'{int(height)}\n{percentage}'
        ax.text(p.get_x() + p.get_width() / 2, height/2, text_label, ha='center', va='center', color='black', fontsize=15, fontweight='bold')

# Ajustando o layout para evitar sobreposição e melhorar a apresentação
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.5 Identificação de Outliers nas Variáveis Quantitativas</strong></p>
#
# - **Nesta seção, identificaremos os outliers (valores atípicos) nas variáveis quantitativas utilizando o método do Intervalo Interquartil (IQR).**
# - **Outliers podem indicar dados errôneos, mas também podem fornecer informações importantes sobre comportamentos extremos. No entanto, sua presença pode distorcer análises e modelos, por isso é essencial identificá-los.**
# - **A fórmula utilizada para calcular os outliers é baseada no IQR:**
#   - **Q1**: Primeiro quartil (25%).
#   - **Q3**: Terceiro quartil (75%).
#   - **IQR = Q3 - Q1**.
#   - **Limite inferior = Q1 - 1.5 * IQR**.
#   - **Limite superior = Q3 + 1.5 * IQR**.
# - **Valores fora desses limites são considerados outliers. A tabela a seguir mostra a quantidade de outliers identificados em cada variável.**
#
# </div>

# %%
# Função para calcular a quantidade de outliers em cada variável usando IQR
def contar_outliers(df, colunas_quantitativas):
    outliers_dict = {}

    for coluna in colunas_quantitativas:
        Q1 = df[coluna].quantile(0.25)
        Q3 = df[coluna].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Contando os outliers abaixo e acima dos limites
        outliers_abaixo = df[df[coluna] < lower_bound].shape[0]
        outliers_acima = df[df[coluna] > upper_bound].shape[0]
        total_outliers = outliers_abaixo + outliers_acima

        # Adicionando à lista de outliers
        outliers_dict[coluna] = {
            'Outliers Abaixo': outliers_abaixo,
            'Outliers Acima': outliers_acima,
            'Total de Outliers': total_outliers
        }

    return pd.DataFrame(outliers_dict).T

# Aplicando a função para as variáveis quantitativas
tabela_outliers = contar_outliers(df, colunas_quantitativas)

# Exibindo a tabela de frequência de outliers
tabela_outliers
# Out:
#                       Outliers Abaixo  Outliers Acima  Total de Outliers
# pontuacao_credito                  15               0                 15
# idade                               0             359                359
# tempo_relacionamento                0               0                  0
# saldo                               0               0                  0
# numero_produtos                     0              60                 60
# salario_estimado                    0               0                  0

# %% [markdown]
# ---
#
# ### Observações:
#
# - **Pontuação de Crédito**: Foram identificados **15 outliers** abaixo do limite inferior. Isso pode indicar clientes com pontuações de crédito anormalmente baixas, que podem estar mais propensos a dar churn ou com histórico financeiro problemático.
# - **Idade**: Identificamos **359 outliers** acima do limite superior, o que sugere a presença de muitos clientes em faixas etárias mais altas (acima de 60 anos). Isso pode ser um indicador importante a ser analisado em relação ao churn, já que clientes mais velhos podem ter comportamentos diferentes dos mais jovens.
# - **Número de Produtos**: Encontramos **60 outliers** acima do limite superior, ou seja, clientes que utilizam 3 ou mais produtos bancários. Esses clientes podem estar mais engajados com o banco, o que pode influenciar nas análises de churn.
# - **Saldo, Tempo de Relacionamento e Salário Estimado**: Não foram identificados outliers nessas variáveis, o que sugere uma distribuição mais homogênea desses dados no conjunto.
#
# Esses outliers serão mantidos para análise, pois podem fornecer informações valiosas sobre comportamentos extremos de churn. Embora em alguns casos os outliers possam distorcer as análises, neste contexto, eles podem revelar padrões importantes para a retenção ou saída dos clientes do banco.

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.6 Correlações com a Variável de Interesse: Saiu do Banco</strong></p>
#
# - **Nesta etapa, analisaremos a correlação entre as variáveis quantitativas e a variável saiu_banco, que representa o churn. O objetivo é identificar quais variáveis possuem maior correlação com a saída dos clientes.**
#
# - **As correlações nos ajudam a identificar relações lineares entre variáveis e a variável de interesse. A seguir, exibimos a matriz de correlação, que mostra o grau de correlação entre saiu_banco e as demais variáveis numéricas.**
#
# </div>

# %%
# Calculando a matriz de correlação apenas para colunas numéricas
correlation_matrix = df.corr(numeric_only=True)

# Exibindo a matriz de correlação
correlation_matrix
# Out:
#                        pontuacao_credito     idade  tempo_relacionamento  \
# pontuacao_credito               1.000000 -0.003965              0.000842
# idade                          -0.003965  1.000000             -0.009997
# tempo_relacionamento            0.000842 -0.009997              1.000000
# saldo                           0.006268  0.028308             -0.012254
# numero_produtos                 0.012238 -0.030680              0.013444
# possui_cartao_credito          -0.005458 -0.011721              0.022583
# membro_ativo                    0.025651  0.085472             -0.028362
# salario_estimado               -0.001384 -0.007201              0.007784
# saiu_banco                     -0.027094  0.285323             -0.014001
#
#                           saldo  numero_produtos  possui_cartao_credito  \
# pontuacao_credito      0.006268         0.012238              -0.005458
# idade                  0.028308        -0.030680              -0.011721
# ...

# %%
# Definindo a paleta de cores em tons de azul
blue_palette = sns.color_palette("Blues")

# Calculando a matriz de correlação apenas para colunas numéricas
correlation_matrix = df.select_dtypes(include=['float64', 'int64']).corr()

# Criando o mapa de calor
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap=blue_palette, cbar_kws={'label': 'Coeficiente de Correlação'})
plt.title('Mapa de Calor da Correlação entre Variáveis')
plt.show()

# %%
# Filtrando apenas colunas numéricas para evitar o FutureWarning
correlation_matrix = df.select_dtypes(include=['float64', 'int64']).corr()

# Extraindo a correlação das variáveis com a coluna 'saiu_banco' (churn)
correlation_with_churn = correlation_matrix['saiu_banco'].drop('saiu_banco')

# Ordenando do maior para o menor valor absoluto de correlação
correlation_sorted = correlation_with_churn.abs().sort_values(ascending=False)

# Criando um DataFrame para exibir a tabela
correlation_df = pd.DataFrame(correlation_sorted).reset_index()
correlation_df.columns = ['Variável', 'Correlação com Churn']

# Exibindo a tabela
correlation_df
# Out:
#                 Variável  Correlação com Churn
# 0                  idade              0.285323
# 1           membro_ativo              0.156128
# 2                  saldo              0.118533
# 3        numero_produtos              0.047820
# 4      pontuacao_credito              0.027094
# 5   tempo_relacionamento              0.014001
# 6       salario_estimado              0.012097
# 7  possui_cartao_credito              0.007138

# %% [markdown]
# ---
#
# ### Observações:
#
# - A análise de **correlação entre variáveis quantitativas** e o churn mostra que as três variáveis mais fortemente correlacionadas com o churn são:
#   1. **Idade**: A correlação mais forte, com um coeficiente de **0.29**, indicando que clientes mais velhos têm maior probabilidade de deixar o banco.
#   2. **Membro ativo**: Uma correlação negativa moderada de **-0.16**, sugerindo que clientes menos ativos tendem a sair mais.
#   3. **Saldo bancário**: Uma correlação positiva de **0.12**, o que pode indicar que clientes com saldos mais elevados estão deixando o banco, o que merece uma análise mais profunda para entender as razões.
#
# - Outras variáveis como **quantidade de produtos bancários** (**0.05**), **pontuação de crédito** (**0.03**), **tempo de relacionamento** (**0.01**), e **salário estimado** (**0.01**) apresentam correlações mais fracas, indicando que têm menos impacto direto sobre o churn.
#
# Essas observações serão úteis para direcionar a análise futura, permitindo um foco maior nas variáveis mais correlacionadas, como idade, atividade no banco e saldo bancário, ao investigar estratégias para retenção de clientes.

# %%
# Função para gerar uma tabela comparativa entre churn e cada variável categórica
def gerar_tabela_comparativa(df, colunas_qualitativas, target='saiu_banco'):
    tabelas = {}
    
    for coluna in colunas_qualitativas:
        if coluna != target:  # Não incluir o target ele mesmo
            # Gerando a tabela de frequências cruzadas
            tabela = pd.crosstab(df[coluna], df[target], normalize='index') * 100
            tabela.columns = ['Não Saiu (%)', 'Saiu (%)']
            tabelas[coluna] = tabela
            
    return tabelas

# Gerando as tabelas comparativas
tabelas_comparativas = gerar_tabela_comparativa(df, colunas_qualitativas)

# Exibindo as tabelas
for coluna, tabela in tabelas_comparativas.items():
    print(f"Tabela Comparativa para {coluna}:")
    print(tabela)
    print("\n")
# Out:
# Tabela Comparativa para pais:
#           Não Saiu (%)   Saiu (%)
# pais
# Alemanha     67.556796  32.443204
# Espanha      83.326605  16.673395
# França       83.845233  16.154767
#
#
# Tabela Comparativa para genero:
#            Não Saiu (%)   Saiu (%)
# genero
# Feminino      74.928461  25.071539
# Masculino     83.544072  16.455928
#
#
# Tabela Comparativa para possui_cartao_credito:
#                        Não Saiu (%)   Saiu (%)
# possui_cartao_credito
# 0                         79.185059  20.814941
# 1                         79.815734  20.184266
#
#
# Tabela Comparativa para membro_ativo:
#               Não Saiu (%)   Saiu (%)
# membro_ativo
# 0                73.149103  26.850897
# 1                85.730926  14.269074

# %%
# Configurações visuais para todos os gráficos
sns.set(style="whitegrid")
blue_palette = sns.color_palette("Blues")

# Removendo a variável 'saiu_banco' das categóricas, já que não faz sentido plotar ela com ela mesma
colunas_qualitativas_sem_churn = [col for col in colunas_qualitativas if col != 'saiu_banco']

# Número de variáveis categóricas sem 'saiu_banco'
num_var = len(colunas_qualitativas_sem_churn)

# Determinando o número de linhas e colunas
num_cols = 2  # Dois gráficos por linha
num_rows = (num_var + num_cols - 1) // num_cols  # Calcula o número necessário de linhas, arredondado para cima

# Criando a figura e definindo o número de linhas e colunas para os subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 5 * num_rows))

# Loop para plotar gráficos de barras comparando cada variável categórica com churn
for i, coluna in enumerate(colunas_qualitativas_sem_churn):
    ax = axes[i // num_cols, i % num_cols]  # Encontra o subplot correspondente
    churn_plot = sns.countplot(x=coluna, hue='saiu_banco', data=df, palette=blue_palette, ax=ax)
    
    ax.set_title(f'Distribuição de {coluna} por Churn')
    ax.set_xlabel(coluna)
    ax.set_ylabel('Contagem')
    ax.legend(title='Churn (saiu_banco)', loc='upper right')

    # Exibir porcentagens em cada barra
    total_counts = df[coluna].value_counts().sum()  # Total de contagem
    for p in churn_plot.patches:
        height = p.get_height()
        percentage = f'{(height / total_counts) * 100:.1f}%'
        churn_plot.text(p.get_x() + p.get_width() / 2, height, percentage, ha='center', va='bottom', fontsize=12)

# Ajustando o layout para evitar sobreposição e melhorar a apresentação
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Observações:
#
# - A análise de **variáveis categóricas** em relação ao churn nos revela alguns padrões importantes:
#
#   1. **País**:
#      - A **Alemanha** apresenta uma taxa de churn de **32%**, a mais alta entre os três países, enquanto **França** e **Espanha** possuem taxas mais baixas, em torno de **16-17%**. Isso sugere que o país de origem pode ser um fator relevante no churn e deve ser investigado mais a fundo.
#
#   2. **Gênero**:
#      - A taxa de churn entre **clientes femininos** é significativamente maior (**25%**) em comparação com os **clientes masculinos** (**16%**). Isso indica uma possível diferença no comportamento de churn entre gêneros, que pode ser explorada em estratégias de retenção personalizadas.
#
#   3. **Posse de Cartão de Crédito**:
#      - Não se observa uma diferença significativa no churn entre clientes que possuem (**20%**) ou não possuem cartão de crédito (**21%**). Este resultado sugere que a posse de cartão de crédito, isoladamente, pode não ser um preditor forte de churn.
#
#   4. **Membro Ativo**:
#      - A **atividade no banco** se mostra como um fator crítico para o churn. Clientes **não ativos** têm uma taxa de churn muito mais alta (**26%**) em comparação com os **clientes ativos** (**14%**). Este achado destaca a importância de manter os clientes engajados com os serviços bancários.
#
# Essas observações destacam as variáveis mais relevantes para analisar em maior detalhe, especialmente **país**, **gênero** e **atividade no banco**, que parecem ter um impacto significativo sobre o churn. A partir dessas análises, podemos direcionar estratégias mais eficazes para retenção de clientes.

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">
#
# ### <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>6.7 Análise Detalhada de Variáveis com Maior Impacto no Churn</strong></p>
#
# - **Com base nas correlações analisadas e nas tendências observadas, decidimos aprofundar a análise nas variáveis que apresentaram maior impacto em relação ao churn, tanto quantitativas quanto categóricas:**
#
#     - **Variáveis Quantitativas:**
#         1. **Idade**: A correlação mais forte foi observada entre idade e churn, com clientes mais velhos tendo maior probabilidade de sair do banco.
#         2. **Saldo Bancário**: Embora a correlação não tenha sido tão alta quanto a idade, clientes com saldos elevados parecem mais propensos a deixar o banco, o que requer uma análise mais detalhada.
#
#     - **Variáveis Categóricas:**
#         1. **Membro Ativo**: Houve uma diferença significativa entre clientes ativos e inativos, sugerindo que a inatividade está fortemente ligada a uma maior taxa de churn.
#         2. **Gênero**: Observamos diferenças notáveis nas taxas de churn entre clientes masculinos e femininos.
#         3. **País**: Diferenças nas taxas de churn foram observadas entre os países, especialmente entre clientes da França, Alemanha e Espanha.
#
# - **Nesta etapa, realizaremos as seguintes ações:**
#     - **Análise da Idade**: Verificar a distribuição de idade entre clientes que saíram e os que permaneceram, segmentando em faixas etárias.
#     - **Análise do Saldo Bancário**: Observar a distribuição do saldo entre clientes que saíram e os que permaneceram, identificando faixas de risco.
#     - **Análise do Membro Ativo**: Comparar a taxa de churn entre clientes ativos e inativos, explorando possíveis padrões de inatividade.
#     - **Análise do Gênero**: Investigar a relação entre gênero e churn, observando se há uma diferença significativa entre homens e mulheres.
#     - **Análise por País**: Explorar as taxas de churn por país, identificando quais regiões têm clientes mais propensos a sair do banco.
#
# Essas análises nos permitirão entender melhor o perfil dos clientes mais propensos ao churn e fornecer insights mais direcionados para futuras ações estratégicas.
#
# </div>

# %%
# Separando os clientes que saíram e não saíram do banco
clientes_sairam = df[df['saiu_banco'] == 1]
clientes_nao_sairam = df[df['saiu_banco'] == 0]

# Gerando o resumo estatístico (describe) para cada grupo
describe_sairam = clientes_sairam['idade'].describe()
describe_nao_sairam = clientes_nao_sairam['idade'].describe()

# Concatenando os dois DataFrames lado a lado
describe_comparativo = pd.concat([describe_nao_sairam, describe_sairam], axis=1, keys=['Não Saíram', 'Saíram'])

# Exibindo a tabela comparativa
print(describe_comparativo)

# Criando o boxplot da distribuição de idades por churn
plt.figure(figsize=(10, 6))
sns.boxplot(x='saiu_banco', y='idade', data=df, palette=blue_palette)

# Definindo os títulos e rótulos
plt.title('Distribuição da Idade por Churn', fontsize=16)
plt.xlabel('Churn (saiu_banco)', fontsize=12)
plt.ylabel('Idade', fontsize=12)
plt.xticks([0, 1], ['Não Saiu', 'Saiu'])

plt.tight_layout()
plt.show()
# Out:
#         Não Saíram       Saíram
# count  7963.000000  2037.000000
# mean     37.408389    44.837997
# std      10.125363     9.761562
# min      18.000000    18.000000
# 25%      31.000000    38.000000
# 50%      36.000000    45.000000
# 75%      41.000000    51.000000
# max      92.000000    84.000000

# %% [markdown]
# ---
#
# ### Observações:
#
# - A análise da **distribuição de idade por churn** revela alguns insights importantes:
#
#   1. **Distribuição de Idade**:
#      - Clientes que **deixaram o banco** tendem a ter uma **idade mais avançada** comparado aos que permaneceram. O **boxplot** mostra que a mediana de idade daqueles que saíram é significativamente maior, com a maioria dos clientes que deram churn tendo mais de **40 anos**.
#
#   2. **Quartis de Idade**:
#      - A divisão das idades em **quartis** foi escolhida para uma análise mais granular. Isso permite observar como diferentes **faixas etárias** se comportam em relação ao churn, oferecendo uma visão mais clara sobre quais grupos etários podem estar mais propensos a sair do banco.
#
#   3. **Distribuição por Quartis**:
#      - Espera-se que a **faixa de clientes mais velhos** (quartil superior) apresente uma maior tendência ao churn, enquanto os **clientes mais jovens** (quartil inferior) devem ter uma menor taxa de saída.
#
# Essas observações nos motivam a investigar mais detalhadamente as faixas etárias, com o objetivo de identificar **padrões de churn relacionados à idade** e pensar em estratégias para reter clientes mais velhos, que parecem estar saindo em maior proporção.

# %%
# Definindo os limites dos quartis e rotulando com as faixas de idade correspondentes
bins = [df['idade'].min(), df['idade'].quantile(0.25), df['idade'].quantile(0.5), df['idade'].quantile(0.75), df['idade'].max()]
labels = [f'{int(bins[i])}-{int(bins[i+1]-1)}' for i in range(len(bins)-1)]  # Criando os rótulos com as faixas de idade

# Criando uma nova coluna para as faixas de idade
df['faixa_etaria_quartil'] = pd.cut(df['idade'], bins=bins, labels=labels, include_lowest=True)

# Criando a tabela de frequência de churn para cada faixa etária
churn_faixa_etaria = pd.crosstab(df['faixa_etaria_quartil'], df['saiu_banco'], normalize='index') * 100
churn_faixa_etaria.columns = ['Não Saiu (%)', 'Saiu (%)']

# Exibindo a tabela
print(churn_faixa_etaria)

# Plotando o gráfico de barras para a comparação entre quem saiu e quem não saiu em cada faixa etária
plt.figure(figsize=(10, 6))
churn_plot = churn_faixa_etaria.plot(kind='bar', stacked=False, color=sns.color_palette("Blues", 2), figsize=(10, 6))

plt.title('Distribuição do Churn por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Porcentagem de Clientes')
plt.xticks(rotation=0)

# Exibindo as porcentagens diretamente nas barras
for p in churn_plot.patches:
    churn_plot.annotate(f'{p.get_height():.1f}%', 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
#                       Não Saiu (%)   Saiu (%)
# faixa_etaria_quartil
# 18-31                    92.365591   7.634409
# 32-36                    89.159774  10.840226
# 37-43                    79.362612  20.637388
# 44-91                    55.384615  44.615385

# %% [markdown]
# ---
#
# ### Observações:
#
# - A análise das faixas etárias, divididas pelos quartis, revela uma tendência clara de **maior churn em clientes mais velhos**:
#
#   1. **18-31 anos**: Esta faixa etária tem a menor taxa de churn, com **apenas 7.6%** dos clientes deixando o banco. A grande maioria dos clientes mais jovens tende a permanecer, com **92.4%** dos clientes ainda ativos.
#
#   2. **32-36 anos**: A taxa de churn aumenta levemente para **10.8%**, mas ainda se observa que a maioria dos clientes nessa faixa etária continua no banco (**89.2%**).
#
#   3. **37-43 anos**: A partir desta faixa etária, vemos um aumento significativo no churn, com **20.6%** dos clientes saindo do banco. A taxa de retenção diminui para **79.4%**.
#
#   4. **44-91 anos**: A faixa etária mais velha apresenta a maior taxa de churn, com **44.6%** dos clientes deixando o banco. Isso representa uma mudança drástica em comparação com as faixas etárias mais jovens, sugerindo que clientes mais velhos estão significativamente mais propensos a sair.
#
# Essas observações sugerem que a **idade** é um fator determinante para o churn, especialmente entre os clientes mais velhos. Estratégias de retenção específicas para esse grupo etário podem ser uma abordagem eficaz para reduzir as taxas de churn.

# %%
# Separando os clientes que saíram e não saíram do banco
clientes_sairam = df[df['saiu_banco'] == 1]
clientes_nao_sairam = df[df['saiu_banco'] == 0]

# Gerando o resumo estatístico (describe) para saldo de cada grupo
describe_sairam_saldo = clientes_sairam['saldo'].describe()
describe_nao_sairam_saldo = clientes_nao_sairam['saldo'].describe()

# Concatenando os dois DataFrames lado a lado
describe_comparativo_saldo = pd.concat([describe_nao_sairam_saldo, describe_sairam_saldo], axis=1, keys=['Não Saíram', 'Saíram'])

# Exibindo a tabela comparativa de saldo
print(describe_comparativo_saldo)

# Criando o boxplot da distribuição de saldo por churn
plt.figure(figsize=(10, 6))
sns.boxplot(x='saiu_banco', y='saldo', data=df, palette=blue_palette)

# Definindo os títulos e rótulos
plt.title('Distribuição do Saldo por Churn', fontsize=16)
plt.xlabel('Churn (saiu_banco)', fontsize=12)
plt.ylabel('Saldo', fontsize=12)
plt.xticks([0, 1], ['Não Saiu', 'Saiu'])

plt.tight_layout()
plt.show()
# Out:
#           Não Saíram         Saíram
# count    7963.000000    2037.000000
# mean    72745.296779   91108.539337
# std     62848.040701   58360.794816
# min         0.000000       0.000000
# 25%         0.000000   38340.020000
# 50%     92072.680000  109349.290000
# 75%    126410.280000  131433.330000
# max    221532.800000  250898.090000

# %% [markdown]
# ---
#
# ### Observações:
#
# - A análise da distribuição do saldo bancário entre os clientes que saíram e os que permaneceram no banco revela diferenças significativas:
#
#   1. **Clientes que não saíram (Churn = 0)**
#      - Esses clientes possuem um saldo médio de 72.745, com a mediana em 92.072. Isso indica que, em geral, clientes que permanecem no banco tendem a ter saldos bancários mais baixos em comparação com aqueles que saíram.
#
#   2. **Clientes que saíram (Churn = 1)**
#      - Os clientes que deixaram o banco possuem um saldo médio significativamente mais alto, 91.108, com uma mediana de 109.349. Esses clientes apresentam uma maior dispersão nos valores de saldo, o que sugere que aqueles com saldos mais elevados estão deixando o banco.
#
#   3. **Dispersão de saldos**
#      - A análise do boxplot revela que a dispersão dos saldos é mais pronunciada entre os clientes que saíram, com maior concentração de clientes com saldos mais altos em comparação aos que permaneceram. Isso pode indicar que o banco pode estar perdendo clientes com maior poder aquisitivo.
#
#   4. **Saldo Zero**
#      - Tanto clientes que saíram quanto os que ficaram têm uma proporção significativa de saldo zero, o que sugere que o saldo em si pode não ser o único fator determinante para o churn.
#
# Essas observações indicam que o saldo bancário, principalmente em valores mais elevados, pode ser um fator importante para explicar o churn. A próxima etapa será dividir os clientes em faixas de saldo para entender melhor a relação entre diferentes níveis de saldo e a probabilidade de churn.

# %%
# Definindo faixas personalizadas de saldo com rótulos numéricos
bins_saldo = [df['saldo'].min(), 0.01, 50000, 100000, 150000, df['saldo'].max()]
labels_saldo = ['0', '0.01-50K', '50K-100K', '100K-150K', '150K-250K']  # Rótulos com faixas de valores numéricos

# Criando uma nova coluna para as faixas de saldo
df['faixa_saldo_personalizada'] = pd.cut(df['saldo'], bins=bins_saldo, labels=labels_saldo, include_lowest=True)

# Criando a tabela de frequência de churn para cada faixa de saldo
churn_faixa_saldo_personalizada = pd.crosstab(df['faixa_saldo_personalizada'], df['saiu_banco'], normalize='index') * 100
churn_faixa_saldo_personalizada.columns = ['Não Saiu (%)', 'Saiu (%)']

# Exibindo a tabela
print(churn_faixa_saldo_personalizada)

# Plotando o gráfico de barras para a comparação entre quem saiu e quem não saiu em cada faixa de saldo
plt.figure(figsize=(10, 6))
churn_plot_saldo_personalizado = churn_faixa_saldo_personalizada.plot(kind='bar', stacked=False, color=sns.color_palette("Blues", 2), figsize=(10, 6))

plt.title('Distribuição do Churn por Faixa de Saldo')
plt.xlabel('Faixa de Saldo')
plt.ylabel('Porcentagem de Clientes')
plt.xticks(rotation=0)

# Exibindo as porcentagens diretamente nas barras
for p in churn_plot_saldo_personalizado.patches:
    churn_plot_saldo_personalizado.annotate(f'{p.get_height():.1f}%', 
                                            (p.get_x() + p.get_width() / 2., p.get_height()), 
                                            ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
#                            Não Saiu (%)   Saiu (%)
# faixa_saldo_personalizada
# 0                             86.176389  13.823611
# 0.01-50K                      65.333333  34.666667
# 50K-100K                      80.119284  19.880716
# 100K-150K                     74.229765  25.770235
# 150K-250K                     76.883385  23.116615

# %% [markdown]
# ---
#
# ### Observações Preliminares:
#
# - A análise das **faixas de saldo bancário** revela alguns padrões em relação ao churn, mas não permite cravar uma relação totalmente clara e determinante:
#
#   1. **Saldo igual a 0**: Clientes com saldo igual a zero apresentam uma taxa de churn relativamente baixa, com **apenas 13.8%** deles saindo do banco. A grande maioria (**86.2%**) desses clientes permanece no banco, sugerindo que o saldo zero, por si só, não é um fator determinante para o churn.
#
#   2. **Saldo entre 0.01 e 50K**: A taxa de churn é significativamente maior nesta faixa, com **34.7%** dos clientes saindo do banco. Isso sugere que clientes com saldos relativamente baixos podem estar mais propensos a deixar o banco, mas há exceções a essa regra.
#
#   3. **Saldo entre 50K e 100K**: Nessa faixa, a taxa de churn diminui para **19.9%**, e a maioria dos clientes (**80.1%**) continua ativa. Esse nível de saldo parece indicar uma maior retenção de clientes, mas sem uma correlação totalmente sólida.
#
#   4. **Saldo entre 100K e 150K**: A taxa de churn volta a aumentar para **25.8%**, o que mostra que, apesar de terem saldos consideráveis, muitos clientes dessa faixa optaram por sair do banco.
#
#   5. **Saldo entre 150K e 250K**: Clientes com saldos elevados, nessa faixa, têm uma taxa de churn de **23.1%**, com **76.9%** dos clientes ainda ativos. Embora seja um saldo alto, essa faixa ainda apresenta uma taxa considerável de churn, o que pode sugerir outros fatores além do saldo influenciando a decisão de sair.
#
# - **Conclusão**: Apesar de algumas faixas de saldo indicarem um risco maior de churn, como no caso dos clientes com saldo entre **0.01 e 50K**, a relação entre saldo bancário e churn não é linear ou definitiva. Isso indica que, embora o saldo seja um fator relevante, outros aspectos provavelmente desempenham um papel importante na decisão de saída dos clientes.

# %%
# Criando a tabela de contingência para membro ativo e churn
tabela_membro_ativo_churn = pd.crosstab(df['membro_ativo'], df['saiu_banco'], normalize='index') * 100
tabela_membro_ativo_churn.columns = ['Não Saiu (%)', 'Saiu (%)']

# Exibindo a tabela de contingência
print(tabela_membro_ativo_churn)

# Plotando um gráfico de barras lado a lado para a comparação
plt.figure(figsize=(8, 6))
tabela_membro_ativo_churn.plot(kind='bar', stacked=False, color=sns.color_palette("Blues", 2), figsize=(8, 6))

# Adicionando rótulos e títulos
plt.title('Distribuição de Membro Ativo por Churn', fontsize=16)
plt.xlabel('Membro Ativo (0 = Não, 1 = Sim)', fontsize=12)
plt.ylabel('Porcentagem de Clientes', fontsize=12)
plt.xticks(rotation=0)

# Exibindo as porcentagens diretamente nas barras
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}%', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
#               Não Saiu (%)   Saiu (%)
# membro_ativo
# 0                73.149103  26.850897
# 1                85.730926  14.269074

# %% [markdown]
# ---
#
# ### Observações:
#
# - A análise da variável **membro ativo** em relação ao churn confirma que clientes que são **mais ativos** tendem a ter uma probabilidade **significativamente menor** de deixar o banco:
#
#   1. **Clientes não ativos (0)**: Aproximadamente **26.9%** dos clientes que não são membros ativos acabaram saindo do banco. Isso indica que **clientes menos engajados** têm maior propensão ao churn.
#
#   2. **Clientes ativos (1)**: Por outro lado, apenas **14.3%** dos clientes que são membros ativos deixaram o banco, o que sugere que **manter o cliente ativo** é uma estratégia fundamental para aumentar a retenção.
#
# - Vale ressaltar que, com o dataset atual, não temos informações detalhadas sobre as **regras de negócios** ou **critérios específicos** que determinam quando um cliente é considerado "ativo". Assim, seria interessante explorar essas definições para uma análise mais completa no futuro.

# %%
# Criando a tabela de frequência de churn para cada gênero
tabela_genero_churn = pd.crosstab(df['genero'], df['saiu_banco'], normalize='index') * 100
tabela_genero_churn.columns = ['Não Saiu (%)', 'Saiu (%)']

# Exibindo a tabela
print(tabela_genero_churn)

# Plotando um gráfico de barras lado a lado para a comparação
plt.figure(figsize=(8, 6))
tabela_genero_churn.plot(kind='bar', stacked=False, color=sns.color_palette("Blues", 2), figsize=(8, 6))

# Adicionando rótulos e títulos
plt.title('Distribuição de Gênero por Churn', fontsize=16)
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Porcentagem de Clientes', fontsize=12)
plt.xticks(rotation=0)

# Exibindo as porcentagens diretamente nas barras
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}%', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
#            Não Saiu (%)   Saiu (%)
# genero
# Feminino      74.928461  25.071539
# Masculino     83.544072  16.455928

# %% [markdown]
# ---
#
# ### Observações Preliminares:
#
# - A análise do **gênero** em relação ao churn revela algumas diferenças notáveis:
#
#   1. **Clientes Femininos**: As mulheres têm uma taxa de churn mais alta, com **25%** delas deixando o banco. Isso indica uma maior tendência de churn entre clientes do gênero feminino em comparação com o masculino.
#
#   2. **Clientes Masculinos**: Em contraste, a taxa de churn entre os homens é menor, com **16.5%** deles saindo do banco, o que mostra uma maior retenção neste grupo.
#
# Essas observações indicam que o **gênero** pode ser um fator importante a ser considerado em estratégias de retenção, com a necessidade de investigar mais profundamente os motivos pelos quais o churn é mais alto entre as mulheres e se há fatores específicos que influenciam essa tendência.

# %%
# Gerando a tabela de frequência de churn para cada país
tabela_pais_churn = pd.crosstab(df['pais'], df['saiu_banco'], normalize='index') * 100
tabela_pais_churn.columns = ['Não Saiu (%)', 'Saiu (%)']

# Exibindo a tabela comparativa
print(tabela_pais_churn)

# Plotando um gráfico de barras lado a lado para a comparação
plt.figure(figsize=(8, 6))
tabela_pais_churn.plot(kind='bar', stacked=False, color=sns.color_palette("Blues", 2), figsize=(8, 6))

# Adicionando rótulos e títulos
plt.title('Distribuição de Churn por País', fontsize=16)
plt.xlabel('País', fontsize=12)
plt.ylabel('Porcentagem de Clientes', fontsize=12)
plt.xticks(rotation=0)

# Exibindo as porcentagens diretamente nas barras
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1f}%', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
#           Não Saiu (%)   Saiu (%)
# pais
# Alemanha     67.556796  32.443204
# Espanha      83.326605  16.673395
# França       83.845233  16.154767

# %% [markdown]
# ---
#
# ### Observações:
#
# - A análise das variáveis relacionadas ao **país** revela algumas diferenças significativas nas taxas de churn entre os países:
#
#   1. **Alemanha**: Este país apresenta a maior taxa de churn, com **32.4%** dos clientes deixando o banco. Essa porcentagem é consideravelmente maior do que em outros países, indicando que os clientes alemães podem ser mais propensos a sair ou que podem haver fatores específicos no atendimento ou nas políticas direcionadas a esse público.
#
#   2. **Espanha**: A taxa de churn na Espanha é de **16.7%**, significativamente menor do que a observada na Alemanha. A maioria dos clientes espanhóis tende a permanecer no banco (**83.3%**).
#
#   3. **França**: A França apresenta a menor taxa de churn entre os três países, com **16.2%** dos clientes deixando o banco. Esse resultado sugere que os clientes franceses são mais estáveis ou têm maior satisfação com os serviços bancários.
#
# Essas observações sugerem que o **país** de residência é um fator importante a ser considerado nas análises de churn, sendo necessário investigar mais a fundo por que os clientes da **Alemanha** estão saindo em maior proporção em comparação com os outros países.

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="7"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>7. INSIGHTS E CONCLUSÕES 🔍</strong></p>
#
# - **Esta seção apresenta os principais insights e conclusões obtidos a partir da análise exploratória dos dados do Blue Bank. Os insights são derivados das respostas às perguntas de negócio formuladas anteriormente e são fundamentais para orientar as estratégias de retenção de clientes do banco.**
#
# ### Principais Insights:
#
# 🧓 **Insight 1:** A **idade** é um fator chave no churn. Clientes mais velhos (acima de 44 anos) têm uma taxa de churn significativamente maior (44.6%), enquanto os mais jovens (18-31 anos) têm a menor taxa de churn (7.6%). Estratégias de retenção específicas para grupos etários mais avançados podem ser necessárias para diminuir a taxa de churn nesse segmento.
#
# 🏦 **Insight 2:** A **atividade bancária** tem impacto direto no churn. Clientes **menos ativos** apresentam uma taxa de churn muito mais alta (26.9%) em comparação aos **clientes ativos** (14.3%). Isso destaca a importância de manter os clientes engajados e ativos nos serviços bancários.
#
# 👩‍💼 **Insight 3:** A **diferença de churn por gênero** é um ponto relevante. A taxa de churn entre clientes femininos (25%) é maior do que entre os masculinos (16.5%). Esse dado pode ser explorado para criar estratégias mais personalizadas para retenção de clientes do gênero feminino.
#
# 💰 **Insight 4:** O **saldo bancário** não apresenta uma relação linear clara com o churn. Clientes com saldo zero, por exemplo, mostram uma taxa de churn baixa (13.8%), enquanto aqueles com saldos entre **0.01 e 50K** têm uma taxa de churn mais alta (34.7%). No entanto, saldos mais altos não necessariamente garantem menor churn.
#
# 🌍 **Insight 5:** O **país** de origem é um fator significativo. Clientes da **Alemanha** apresentam uma taxa de churn maior (32.4%) do que clientes da França (16.2%) e Espanha (16.7%). Isso sugere a necessidade de investigar as particularidades de cada país para compreender as causas dessa discrepância e melhorar a retenção.
#
# ### Conclusões:
#
# 🧠 **Conclusão 1:** A análise revelou que **idade**, **membro ativo**, e **gênero** são as variáveis mais relevantes para explicar o churn. Estratégias de retenção devem focar nesses aspectos, com campanhas voltadas para clientes mais velhos e menos ativos, além de uma atenção especial às diferenças de gênero.
#
# 🔑 **Conclusão 2:** A **atividade bancária** é crucial para retenção. Manter clientes engajados nos serviços do banco deve ser uma prioridade, já que clientes ativos têm uma menor probabilidade de churn.
#
# 💡 **Conclusão 3:** Embora o saldo bancário não tenha mostrado uma relação clara com o churn, é importante observar que clientes com saldos mais altos também estão saindo do banco. A retenção de clientes com maior poder aquisitivo pode ser explorada com incentivos específicos ou melhores serviços personalizados.
#
# ### Impacto Potencial:
#
# - **A retenção de clientes mais velhos**: O foco em clientes com mais de 44 anos pode reduzir significativamente as taxas de churn, que são muito elevadas nessa faixa etária. Ofertas especiais e suporte personalizado para esse grupo devem ser considerados.
# - **Engajamento de clientes inativos**: A criação de incentivos para aumentar a atividade dos clientes, como programas de fidelidade e novos produtos financeiros, pode ajudar a reter clientes que atualmente são menos ativos no banco.
# - **Ajustes por região**: A taxa de churn mais alta na Alemanha em comparação com outros países sugere que estratégias regionais específicas podem ser benéficas para melhorar a retenção e reduzir as taxas de churn em países com maior evasão.
#
# </div>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="8"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>8. RECOMENDAÇÕES 📝</strong></p>
#
# - **Baseadas nos insights derivados da análise exploratória de dados, propomos as seguintes recomendações para o Blue Bank com o objetivo de melhorar a retenção de clientes e reduzir as taxas de churn:**
#
#     - 🧓 **Recomendação 1:** Criar **programas de fidelidade e suporte personalizado** voltados para clientes mais velhos, especialmente aqueles com mais de **44 anos**, que demonstraram maior probabilidade de churn. O foco pode ser em produtos bancários que atendam às necessidades específicas dessa faixa etária, como investimentos de baixo risco e assessoria financeira especializada.
#
#     - 🏦 **Recomendação 2:** Implementar **incentivos para aumentar a atividade** dos clientes menos engajados. Como os dados mostraram que **clientes inativos** são significativamente mais propensos a deixar o banco, o Blue Bank deve considerar ofertas exclusivas, descontos ou notificações personalizadas para incentivar o uso dos serviços bancários por esses clientes.
#
#     - 💡 **Recomendação 3:** **Analisar mais profundamente as diferenças de churn por gênero**. Uma vez que mulheres apresentam uma taxa de churn maior do que homens, é importante investigar os motivos dessa discrepância e, com base nisso, desenvolver estratégias de retenção personalizadas, que possam incluir ofertas de produtos financeiros específicos ou melhorias no atendimento a esse grupo.
#
#     - 🌍 **Recomendação 4:** **Ajustar estratégias de retenção regionalmente**, com foco na Alemanha, onde a taxa de churn é mais alta. O banco pode realizar pesquisas adicionais para entender melhor as necessidades e frustrações dos clientes alemães, além de criar campanhas e benefícios mais direcionados para essa região.
#
#     - 💰 **Recomendação 5:** Oferecer **incentivos específicos para clientes com saldos mais elevados**, especialmente na faixa entre **100K e 150K**, que apresentou uma taxa de churn considerável. O banco pode explorar melhores condições em produtos de investimento ou serviços premium para esse grupo, incentivando-os a continuar no banco.
#
#     - 🔍 **Recomendação 6:** **Monitorar os sinais de churn** de forma proativa. A análise revelou que algumas variáveis, como idade e saldo, são indicativas de maior probabilidade de churn. Utilizar esses dados para prever e agir antes que o cliente tome a decisão de sair pode ser uma maneira eficaz de reduzir o churn. Modelos preditivos de machine learning podem ser explorados futuramente para aprimorar essas intervenções.
#
# - **Essas recomendações são projetadas para serem implementadas de maneira faseada e avaliadas continuamente para eficácia, garantindo que o Blue Bank possa adaptar suas estratégias conforme necessário para maximizar a retenção de clientes.**
#
# </div>

# %% [markdown]
# <div style="font-family: Montserrat; color:#14274C; background-color:#D2E0E9; border-radius:12px 12px;">  <a id="9"></a>
#
# ## <p style="background-color:#14274C; font-family:Montserrat; color:#8BD5EA; font-size:140%; text-align:left; border-radius:10px 10px; margin-bottom: 10px; padding-left: 75px;"><strong>9. CONCLUSÃO 🏁</strong></p>
#
# - **Esta seção final resume os insights chave e as ações recomendadas baseadas na análise exploratória de dados realizada. Refletimos sobre o impacto potencial dessas ações e consideramos os passos futuros para a continuação da melhoria das estratégias de retenção de clientes do Blue Bank.**
#
# ### Pontos Principais:
#
# - A análise revelou que variáveis como **idade**, **saldo bancário** e **membro ativo** têm uma correlação significativa com o churn. Clientes mais velhos e menos ativos têm maior probabilidade de deixar o banco, o que sugere uma necessidade de estratégias de retenção direcionadas a esses grupos.
#
# - **Diferenças regionais** e **gênero** também desempenham um papel importante no churn. Clientes da Alemanha, bem como as mulheres, mostraram-se mais propensos a sair do banco. Esse padrão pode indicar áreas onde o banco pode personalizar seus serviços e melhorar a retenção.
#
# - **Saldo bancário elevado** foi identificado como um fator relevante, pois clientes com saldos maiores apresentam taxas consideráveis de churn. Isso implica que o Blue Bank deve direcionar atenção especial a esse grupo, oferecendo incentivos ou programas específicos.
#
# - As recomendações sugeridas incluem **engajar mais clientes ativos**, melhorar a **personalização de serviços** por região e gênero, além de implementar **monitoramento proativo** com base nos sinais de churn identificados nas análises.
#
# ### Futuras Direções:
#
# - Para **futuras análises**, será essencial integrar **modelos preditivos de machine learning** para antecipar o churn de forma mais eficiente e permitir intervenções mais precisas.
#
# - O banco pode explorar **novos dados comportamentais** e fatores de satisfação do cliente, além de considerar a incorporação de variáveis como **interações com o suporte** e **experiência digital** para um panorama mais completo sobre o comportamento dos clientes.
#
# - Investir em **pesquisas qualitativas** com clientes da Alemanha e mulheres pode trazer insights adicionais sobre as razões do churn e direcionar a criação de novos produtos ou serviços.
#
# - **Análise de carteiras de produtos** pode ajudar a entender melhor o engajamento dos clientes e como diferentes combinações de produtos afetam a retenção.
#
# ### Agradecimentos:
#
# - Agradecemos a todos os envolvidos no projeto, incluindo nossos colegas, mentores e colaboradores que apoiaram o desenvolvimento desta análise e nos ajudaram a alcançar resultados significativos.
#
# </div>
